# %%
import ScraperFC as sfc

ss = sfc.Sofascore()

df = ss.scrape_player_league_stats(
    year="24/25",
    league="La Liga",
    accumulation="per90"
)

print("Columnas disponibles:")
for col in df.columns:
    print(col)
# Out:
# Running
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 5
#       1 import ScraperFC as sfc
#       3 ss = sfc.Sofascore()
# ----> 5 df = ss.scrape_player_league_stats(
#       6     year="24/25",
#       7     league="La Liga",
#       8     accumulation="per90"
#       9 )
#      11 print("Columnas disponibles:")
#      12 for col in df.columns:
#
# File c:\Users\jahoy\Documents\scouting\venv\Lib\site-packages\ScraperFC\sofascore.py:305, in Sofascore.scrape_player_league_stats(self, year, league, accumulation, selected_positions)
#     303 if not isinstance(year, str):
#     304     raise TypeError('`year` must be a string.')
# --> 305 valid_seasons = self.get_valid_seasons(league)
#     306 if year not in valid_seasons.keys():
#     307     raise InvalidYearException(year, league, list(valid_seasons.keys()))
#
# ...

# %%
valid = ss.get_valid_seasons("La Liga")  # o el nombre que te salga en el paso 2
print(valid)              # {'25/26': 7xxxx, '24/25': 6xxxx, ...}
year = "24/25"            # clave EXACTA de ese dict
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 valid = ss.get_valid_seasons("La Liga")  # o el nombre que te salga en el paso 2
#       2 print(valid)              # {'25/26': 7xxxx, '24/25': 6xxxx, ...}
#       3 year = "24/25"            # clave EXACTA de ese dict
#
# File c:\Users\jahoy\Documents\scouting\venv\Lib\site-packages\ScraperFC\sofascore.py:101, in Sofascore.get_valid_seasons(self, league)
#      98     raise InvalidLeagueException(league, 'Sofascore', list(comps.keys()))
#     100 response = botasaurus_browser_get_json(f'{API_PREFIX}/unique-tournament/{comps[league]}/seasons/')
# --> 101 seasons = dict([(x['year'], x['id']) for x in response['seasons']])
#     102 return seasons
#
# KeyError: 'seasons'

# %%
import pandas as pd

df = pd.read_csv("lake/bronze/sofascore/20_21_La_Liga_raw.csv")
print(df.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("lake/bronze/sofascore/20_21_La_Liga_raw.csv")
#       4 print(df.columns.tolist())
#
# ...
